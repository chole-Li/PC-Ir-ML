# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import KFold, GridSearchCV,train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, BaggingRegressor, ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

random_seed = 2024
best_params = {}

param_grid = {
    'RF': {'n_estimators': [50, 75, 100, 200, 300, 400], 'max_depth': [None, 5, 10, 15, 20]},
    'GB': {'n_estimators': [50, 75, 100, 200, 300, 400], 'max_depth': [None, 5, 10, 15, 20]},
    'KNN': {'n_neighbors': [5, 10, 15], 'leaf_size': [25, 30, 35]},
    'DT': {'max_depth': [None, 10, 20], 'min_samples_split': [2, 4, 6]},
    'SVR': {'kernel': ['rbf', 'linear'], 'gamma': ['scale', 'auto', 0.1, 1, 10]}, 
    'BG': {'n_estimators': [50, 75, 100, 200, 300, 400]},
    'ET': {'n_estimators': [50, 75, 100, 200, 300, 400], 'max_depth': [None, 5, 10, 15, 20]}
}

models = {
    "RF": RandomForestRegressor(n_jobs=-1, random_state=random_seed),
    "GB": GradientBoostingRegressor(random_state=random_seed),
    "KNN": KNeighborsRegressor(n_jobs=-1),
    "DT": DecisionTreeRegressor(random_state=random_seed),
    "SVR": SVR(),
    "BG": BaggingRegressor(n_jobs=-1, random_state=random_seed),
    "ET": ExtraTreesRegressor(n_jobs=-1, random_state=random_seed),
}

kfold = KFold(n_splits=10, shuffle=True, random_state=random_seed)

directory = "./result"


datasets = {
    'MF': 'MF-ox.npz',
    'MACCS': 'MACCS-ox.npz',
    'PhO': 'PhO-ox.npz',
    'rdkit': 'rdkit-ox.npz',
    'PhO_rdkit': 'PhO_rdkit.npz',
    'PhO_maccs': 'PhO_maccs.npz',
    'PhO_MF': 'PhO_MF.npz',
    'rdkit_maccs': 'rdkit_maccs.npz',
    'PhO_rdkit_maccs': 'PhO_rdkit_maccs.npz',
    
}

test_index = [87, 381, 316, 120, 479, 448, 197, 507, 198, 379, 508, 313, 265, 449, 453, 89, 292, 88, 121, 266, 454, 455, 447, 456, 271, 
              269, 294, 293, 297, 248, 249, 464, 312, 499, 289, 509, 511, 267, 166, 386, 290, 392, 498, 91, 488, 7, 278, 54, 285, 94, 303, 
              358, 444, 5, 286, 98, 458, 2, 291, 268, 470, 262, 308, 272, 53, 354, 512, 360, 495, 468, 391, 310, 307, 457, 306, 258, 352, 
              305, 357, 131, 362, 42, 311, 460, 304, 510, 298, 263, 350, 368, 100, 115, 61, 500, 56, 90, 442, 277, 487, 309, 0, 1, 356]

External_index = [462,119 ,396, 273, 375, 503, 318, 504, 472, 463, 465, 341, 342, 340, 477, 327, 348, 476,423 ,377, 332, 333, 182, 181,
                  349, 183, 112, 328, 323, 324, 113, 329, 330, 331, 144, 145,149, 150, 153, 151, 152, 154, 147, 485, 148, 482, 370, 373,
                  372, 146, 371]

for desc_name, file_path in datasets.items():
    full_path = os.path.join(directory, file_path)
    if os.path.exists(full_path):
        with np.load(full_path, allow_pickle=True) as npz_file:
            array_data = npz_file['data']
            columns = npz_file['columns']
            df = pd.DataFrame(array_data, columns=columns)

            all_indices = set(range(len(df)))  
            train_val_indices = sorted(list(all_indices - set(test_index) - set(External_index))) 
            X = df.drop(columns=['YRed/Ox', 'compound_name'])
            y = df['YRed/Ox']

            scaler = StandardScaler()
            X_scaled = scaler.fit_transform(X.iloc[train_val_indices])
            y_train_val = y.iloc[train_val_indices]

            for model_name, model in models.items():
                if model_name in param_grid:
                    GS = GridSearchCV(model, param_grid[model_name], cv=kfold, n_jobs=-1, scoring='r2')
                    GS.fit(X_scaled, y_train_val)
                    best_score = GS.best_score_
                    best_param = GS.best_params_
                    best_params[(model_name, desc_name)] = best_param
                    print(f"Dataset: {desc_name}, Model: {model_name}, Best Score: {best_score:.4f}, Best Params: {best_param}")
# Out:
# Dataset: MF, Model: RF, Best Score: 0.5031, Best Params: {'max_depth': None, 'n_estimators': 75}
# Dataset: MF, Model: GB, Best Score: 0.5004, Best Params: {'max_depth': 5, 'n_estimators': 300}
# Dataset: MF, Model: KNN, Best Score: 0.2314, Best Params: {'leaf_size': 25, 'n_neighbors': 5}
# Dataset: MF, Model: DT, Best Score: 0.3248, Best Params: {'max_depth': None, 'min_samples_split': 6}
# Dataset: MF, Model: SVR, Best Score: 0.5264, Best Params: {'gamma': 'scale', 'kernel': 'linear'}
# Dataset: MF, Model: BG, Best Score: 0.4994, Best Params: {'n_estimators': 100}
# Dataset: MF, Model: ET, Best Score: 0.3008, Best Params: {'max_depth': None, 'n_estimators': 50}
# Dataset: MACCS, Model: RF, Best Score: 0.5689, Best Params: {'max_depth': 10, 'n_estimators': 100}
# Dataset: MACCS, Model: GB, Best Score: 0.5806, Best Params: {'max_depth': 5, 'n_estimators': 75}
# Dataset: MACCS, Model: KNN, Best Score: 0.2642, Best Params: {'leaf_size': 25, 'n_neighbors': 10}
# Dataset: MACCS, Model: DT, Best Score: 0.3564, Best Params: {'max_depth': 10, 'min_samples_split': 6}
# Dataset: MACCS, Model: SVR, Best Score: 0.5412, Best Params: {'gamma': 'auto', 'kernel': 'rbf'}
# Dataset: MACCS, Model: BG, Best Score: 0.5445, Best Params: {'n_estimators': 100}
# Dataset: MACCS, Model: ET, Best Score: 0.3382, Best Params: {'max_depth': 15, 'n_estimators': 50}
# Dataset: PhO, Model: RF, Best Score: 0.7952, Best Params: {'max_depth': None, 'n_estimators': 300}
# Dataset: PhO, Model: GB, Best Score: 0.8236, Best Params: {'max_depth': 5, 'n_estimators': 75}
# Dataset: PhO, Model: KNN, Best Score: 0.5884, Best Params: {'leaf_size': 25, 'n_neighbors': 5}
# Dataset: PhO, Model: DT, Best Score: 0.6562, Best Params: {'max_depth': 10, 'min_samples_split': 6}
# Dataset: PhO, Model: SVR, Best Score: 0.8812, Best Params: {'gamma': 'scale', 'kernel': 'linear'}
# Dataset: PhO, Model: BG, Best Score: 0.7916, Best Params: {'n_estimators': 400}
# Dataset: PhO, Model: ET, Best Score: 0.7896, Best Params: {'max_depth': 10, 'n_estimators': 75}
# Dataset: rdkit, Model: RF, Best Score: 0.5933, Best Params: {'max_depth': 20, 'n_estimators': 200}
# Dataset: rdkit, Model: GB, Best Score: 0.6139, Best Params: {'max_depth': 5, 'n_estimators': 200}
# Dataset: rdkit, Model: KNN, Best Score: 0.4203, Best Params: {'leaf_size': 25, 'n_neighbors': 5}
# Dataset: rdkit, Model: DT, Best Score: 0.3364, Best Params: {'max_depth': None, 'min_samples_split': 2}
# Dataset: rdkit, Model: SVR, Best Score: 0.5628, Best Params: {'gamma': 'auto', 'kernel': 'rbf'}
# Dataset: rdkit, Model: BG, Best Score: 0.5953, Best Params: {'n_estimators': 200}
# Dataset: rdkit, Model: ET, Best Score: 0.6732, Best Params: {'max_depth': None, 'n_estimators': 50}
# Dataset: PhO_rdkit, Model: RF, Best Score: 0.7924, Best Params: {'max_depth': 15, 'n_estimators': 50}
# Dataset: PhO_rdkit, Model: GB, Best Score: 0.8199, Best Params: {'max_depth': 5, 'n_estimators': 400}
# Dataset: PhO_rdkit, Model: KNN, Best Score: 0.5895, Best Params: {'leaf_size': 25, 'n_neighbors': 5}
# Dataset: PhO_rdkit, Model: DT, Best Score: 0.6925, Best Params: {'max_depth': None, 'min_samples_split': 6}
# Dataset: PhO_rdkit, Model: SVR, Best Score: 0.8235, Best Params: {'gamma': 'scale', 'kernel': 'linear'}
# Dataset: PhO_rdkit, Model: BG, Best Score: 0.7924, Best Params: {'n_estimators': 400}
# Dataset: PhO_rdkit, Model: ET, Best Score: 0.7842, Best Params: {'max_depth': None, 'n_estimators': 400}
# Dataset: PhO_maccs, Model: RF, Best Score: 0.7983, Best Params: {'max_depth': 15, 'n_estimators': 300}
# Dataset: PhO_maccs, Model: GB, Best Score: 0.8244, Best Params: {'max_depth': 5, 'n_estimators': 400}
# Dataset: PhO_maccs, Model: KNN, Best Score: 0.5993, Best Params: {'leaf_size': 25, 'n_neighbors': 5}
# Dataset: PhO_maccs, Model: DT, Best Score: 0.6521, Best Params: {'max_depth': None, 'min_samples_split': 6}
# Dataset: PhO_maccs, Model: SVR, Best Score: 0.8074, Best Params: {'gamma': 'scale', 'kernel': 'linear'}
# Dataset: PhO_maccs, Model: BG, Best Score: 0.7975, Best Params: {'n_estimators': 300}
# Dataset: PhO_maccs, Model: ET, Best Score: 0.8315, Best Params: {'max_depth': 20, 'n_estimators': 75}
# Dataset: PhO_MF, Model: RF, Best Score: 0.7969, Best Params: {'max_depth': 20, 'n_estimators': 300}
# Dataset: PhO_MF, Model: GB, Best Score: 0.8298, Best Params: {'max_depth': 5, 'n_estimators': 300}
# Dataset: PhO_MF, Model: KNN, Best Score: 0.4865, Best Params: {'leaf_size': 25, 'n_neighbors': 5}
# Dataset: PhO_MF, Model: DT, Best Score: 0.6706, Best Params: {'max_depth': 10, 'min_samples_split': 6}
# Dataset: PhO_MF, Model: SVR, Best Score: 0.7791, Best Params: {'gamma': 'scale', 'kernel': 'linear'}
# Dataset: PhO_MF, Model: BG, Best Score: 0.7939, Best Params: {'n_estimators': 300}
# Dataset: PhO_MF, Model: ET, Best Score: 0.7982, Best Params: {'max_depth': 20, 'n_estimators': 300}
# /datapool/home/2022900019/.lico_env/jupyter/env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Dataset: rdkit_maccs, Model: RF, Best Score: 0.6123, Best Params: {'max_depth': 15, 'n_estimators': 200}
# Dataset: rdkit_maccs, Model: GB, Best Score: 0.6005, Best Params: {'max_depth': 5, 'n_estimators': 200}
# Dataset: rdkit_maccs, Model: KNN, Best Score: 0.4449, Best Params: {'leaf_size': 25, 'n_neighbors': 5}
# Dataset: rdkit_maccs, Model: DT, Best Score: 0.2855, Best Params: {'max_depth': 20, 'min_samples_split': 2}
# Dataset: rdkit_maccs, Model: SVR, Best Score: 0.6076, Best Params: {'gamma': 'auto', 'kernel': 'rbf'}
# Dataset: rdkit_maccs, Model: BG, Best Score: 0.6083, Best Params: {'n_estimators': 400}
# Dataset: rdkit_maccs, Model: ET, Best Score: 0.7054, Best Params: {'max_depth': None, 'n_estimators': 100}
# Dataset: PhO_rdkit_maccs, Model: RF, Best Score: 0.7936, Best Params: {'max_depth': None, 'n_estimators': 300}
# Dataset: PhO_rdkit_maccs, Model: GB, Best Score: 0.8215, Best Params: {'max_depth': 5, 'n_estimators': 400}
# Dataset: PhO_rdkit_maccs, Model: KNN, Best Score: 0.6117, Best Params: {'leaf_size': 25, 'n_neighbors': 5}
# Dataset: PhO_rdkit_maccs, Model: DT, Best Score: 0.6315, Best Params: {'max_depth': 10, 'min_samples_split': 4}
# Dataset: PhO_rdkit_maccs, Model: SVR, Best Score: 0.8224, Best Params: {'gamma': 'scale', 'kernel': 'linear'}
# Dataset: PhO_rdkit_maccs, Model: BG, Best Score: 0.7929, Best Params: {'n_estimators': 100}
# Dataset: PhO_rdkit_maccs, Model: ET, Best Score: 0.8209, Best Params: {'max_depth': None, 'n_estimators': 400}

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score
from xgboost import XGBRegressor
from itertools import product

params = {'n_estimators': [50,75,100,200,300,400],'max_depth': [None, 5, 10, 15, 20]}

for desc_name, file_path in datasets.items():
    full_path = os.path.join(directory, file_path)
    if os.path.exists(full_path):
        with np.load(full_path, allow_pickle=True) as npz_file:
            data = npz_file['data']
            columns = npz_file['columns']
            df = pd.DataFrame(data, columns=columns)

            all_indices = set(range(len(df)))
            train_val_indices = sorted(list(all_indices - set(test_index) - set(External_index))) 

            X = df.drop(columns=['YRed/Ox', 'compound_name'])
            y = df['YRed/Ox']

            scaler = StandardScaler()
            X_scaled = scaler.fit_transform(X.iloc[train_val_indices])
            y_train_val = y.iloc[train_val_indices]
            result = []

            for n_estimators, max_depth in product(params['n_estimators'], params['max_depth']):
                model = XGBRegressor(n_estimators=n_estimators, max_depth=max_depth, n_jobs=-1, random_state=random_seed)
                all_test_p = []
                all_test_y = []
                for train_idx, test_idx in kfold.split(X_scaled, y_train_val):
                    train_x, test_x = X_scaled[train_idx], X_scaled[test_idx]
                    train_y, test_y = y_train_val.iloc[train_idx], y_train_val.iloc[test_idx]
                    model.fit(train_x, train_y)
                    all_test_p.append(model.predict(test_x))
                    all_test_y.append(test_y)
                all_test_p = np.concatenate(all_test_p,axis=0)
                all_test_y = np.concatenate(all_test_y,axis=0)
                mae = mean_absolute_error(all_test_y,all_test_p)
                r2 = r2_score(all_test_y,all_test_p)
                result.append([n_estimators,max_depth,mae,r2])
                
            best_result = sorted(result,key=lambda x: x[3], reverse=True)[0]
            best_param = {'n_estimators':best_result[0],'max_depth':best_result[1]}
            best_params[('XGB', desc_name)] = best_param
            print(f'Model: XGB, Dataset: {desc_name}, Best R2 Score: {best_result[3]:.4f}, Best Param: {best_param}')
# Out:
# Model: XGB, Dataset: MF, Best R2 Score: 0.5201, Best Param: {'n_estimators': 100, 'max_depth': None}
# Model: XGB, Dataset: MACCS, Best R2 Score: 0.5890, Best Param: {'n_estimators': 50, 'max_depth': None}
# Model: XGB, Dataset: PhO, Best R2 Score: 0.7668, Best Param: {'n_estimators': 75, 'max_depth': 5}
# Model: XGB, Dataset: rdkit, Best R2 Score: 0.5887, Best Param: {'n_estimators': 50, 'max_depth': 5}
# Model: XGB, Dataset: PhO_rdkit, Best R2 Score: 0.7735, Best Param: {'n_estimators': 50, 'max_depth': 5}
# Model: XGB, Dataset: PhO_maccs, Best R2 Score: 0.7806, Best Param: {'n_estimators': 50, 'max_depth': 5}
# Model: XGB, Dataset: PhO_MF, Best R2 Score: 0.7865, Best Param: {'n_estimators': 50, 'max_depth': 5}
# Model: XGB, Dataset: rdkit_maccs, Best R2 Score: 0.5941, Best Param: {'n_estimators': 75, 'max_depth': 5}
# Model: XGB, Dataset: PhO_rdkit_maccs, Best R2 Score: 0.7607, Best Param: {'n_estimators': 50, 'max_depth': 5}

# %%
best_params
# Out:
# {('RF', 'MF'): {'max_depth': None, 'n_estimators': 75},
#  ('GB', 'MF'): {'max_depth': 5, 'n_estimators': 300},
#  ('KNN', 'MF'): {'leaf_size': 25, 'n_neighbors': 5},
#  ('DT', 'MF'): {'max_depth': None, 'min_samples_split': 6},
#  ('SVR', 'MF'): {'gamma': 'scale', 'kernel': 'linear'},
#  ('BG', 'MF'): {'n_estimators': 100},
#  ('ET', 'MF'): {'max_depth': None, 'n_estimators': 50},
#  ('RF', 'MACCS'): {'max_depth': 10, 'n_estimators': 100},
#  ('GB', 'MACCS'): {'max_depth': 5, 'n_estimators': 75},
#  ('KNN', 'MACCS'): {'leaf_size': 25, 'n_neighbors': 10},
#  ('DT', 'MACCS'): {'max_depth': 10, 'min_samples_split': 6},
#  ('SVR', 'MACCS'): {'gamma': 'auto', 'kernel': 'rbf'},
#  ('BG', 'MACCS'): {'n_estimators': 100},
#  ('ET', 'MACCS'): {'max_depth': 15, 'n_estimators': 50},
#  ('RF', 'PhO'): {'max_depth': None, 'n_estimators': 300},
#  ('GB', 'PhO'): {'max_depth': 5, 'n_estimators': 75},
#  ('KNN', 'PhO'): {'leaf_size': 25, 'n_neighbors': 5},
#  ('DT', 'PhO'): {'max_depth': 10, 'min_samples_split': 6},
#  ('SVR', 'PhO'): {'gamma': 'scale', 'kernel': 'linear'},
#  ('BG', 'PhO'): {'n_estimators': 400},
#  ('ET', 'PhO'): {'max_depth': 10, 'n_estimators': 75},
#  ('RF', 'rdkit'): {'max_depth': 20, 'n_estimators': 200},
#  ('GB', 'rdkit'): {'max_depth': 5, 'n_estimators': 200},
#  ('KNN', 'rdkit'): {'leaf_size': 25, 'n_neighbors': 5},
#  ('DT', 'rdkit'): {'max_depth': None, 'min_samples_split': 2},
#  ('SVR', 'rdkit'): {'gamma': 'auto', 'kernel': 'rbf'},
#  ('BG', 'rdkit'): {'n_estimators': 200},
#  ('ET', 'rdkit'): {'max_depth': None, 'n_estimators': 50},
#  ('RF', 'PhO_rdkit'): {'max_depth': 15, 'n_estimators': 50},
#  ('GB', 'PhO_rdkit'): {'max_depth': 5, 'n_estimators': 400},
#  ('KNN', 'PhO_rdkit'): {'leaf_size': 25, 'n_neighbors': 5},
#  ('DT', 'PhO_rdkit'): {'max_depth': None, 'min_samples_split': 6},
#  ('SVR', 'PhO_rdkit'): {'gamma': 'scale', 'kernel': 'linear'},
#  ('BG', 'PhO_rdkit'): {'n_estimators': 400},
#  ('ET', 'PhO_rdkit'): {'max_depth': None, 'n_estimators': 400},
#  ('RF', 'PhO_maccs'): {'max_depth': 15, 'n_estimators': 300},
#  ('GB', 'PhO_maccs'): {'max_depth': 5, 'n_estimators': 400},
#  ('KNN', 'PhO_maccs'): {'leaf_size': 25, 'n_neighbors': 5},
#  ('DT', 'PhO_maccs'): {'max_depth': None, 'min_samples_split': 6},
#  ('SVR', 'PhO_maccs'): {'gamma': 'scale', 'kernel': 'linear'},
#  ('BG', 'PhO_maccs'): {'n_estimators': 300},
#  ('ET', 'PhO_maccs'): {'max_depth': 20, 'n_estimators': 75},
#  ('RF', 'PhO_MF'): {'max_depth': 20, 'n_estimators': 300},
#  ('GB', 'PhO_MF'): {'max_depth': 5, 'n_estimators': 300},
#  ('KNN', 'PhO_MF'): {'leaf_size': 25, 'n_neighbors': 5},
#  ('DT', 'PhO_MF'): {'max_depth': 10, 'min_samples_split': 6},
#  ('SVR', 'PhO_MF'): {'gamma': 'scale', 'kernel': 'linear'},
#  ('BG', 'PhO_MF'): {'n_estimators': 300},
#  ('ET', 'PhO_MF'): {'max_depth': 20, 'n_estimators': 300},
#  ('RF', 'rdkit_maccs'): {'max_depth': 15, 'n_estimators': 200},
#  ('GB', 'rdkit_maccs'): {'max_depth': 5, 'n_estimators': 200},
#  ('KNN', 'rdkit_maccs'): {'leaf_size': 25, 'n_neighbors': 5},
#  ('DT', 'rdkit_maccs'): {'max_depth': 20, 'min_samples_split': 2},
#  ('SVR', 'rdkit_maccs'): {'gamma': 'auto', 'kernel': 'rbf'},
#  ('BG', 'rdkit_maccs'): {'n_estimators': 400},
#  ('ET', 'rdkit_maccs'): {'max_depth': None, 'n_estimators': 100},
#  ('RF', 'PhO_rdkit_maccs'): {'max_depth': None, 'n_estimators': 300},
#  ('GB', 'PhO_rdkit_maccs'): {'max_depth': 5, 'n_estimators': 400},
#  ('KNN', 'PhO_rdkit_maccs'): {'leaf_size': 25, 'n_neighbors': 5},
#  ('DT', 'PhO_rdkit_maccs'): {'max_depth': 10, 'min_samples_split': 4},
#  ('SVR', 'PhO_rdkit_maccs'): {'gamma': 'scale', 'kernel': 'linear'},
#  ('BG', 'PhO_rdkit_maccs'): {'n_estimators': 100},
#  ('ET', 'PhO_rdkit_maccs'): {'max_depth': None, 'n_estimators': 400},
#  ('XGB', 'MF'): {'n_estimators': 100, 'max_depth': None},
#  ('XGB', 'MACCS'): {'n_estimators': 50, 'max_depth': None},
#  ('XGB', 'PhO'): {'n_estimators': 75, 'max_depth': 5},
#  ('XGB', 'rdkit'): {'n_estimators': 50, 'max_depth': 5},
#  ('XGB', 'PhO_rdkit'): {'n_estimators': 50, 'max_depth': 5},
#  ('XGB', 'PhO_maccs'): {'n_estimators': 50, 'max_depth': 5},
#  ('XGB', 'PhO_MF'): {'n_estimators': 50, 'max_depth': 5},
#  ('XGB', 'rdkit_maccs'): {'n_estimators': 75, 'max_depth': 5},
#  ('XGB', 'PhO_rdkit_maccs'): {'n_estimators': 50, 'max_depth': 5}}

# %%
np.save('./result/hyperparameters_10_opt_new.npy',best_params)

# %% [markdown]
# # Evaluate Different Combinations of ML Model and Descriptor at 10-Fold Cross-Validation

# %% [markdown]
# # Perform model training and validation

# %%
best_params = np.load('./result/hyperparameters_10_opt_new.npy',allow_pickle=True).item()

# %%
from sklearn.ensemble import AdaBoostRegressor, ExtraTreesRegressor
from sklearn.linear_model import BayesianRidge, Ridge
from sklearn.gaussian_process import GaussianProcessRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from scipy.stats import pearsonr
from sklearn.feature_selection import RFECV
import seaborn as sns
import matplotlib.pyplot as plt
import inspect 

def initialize_model(model_name, custom_params=None, random_state=None):
    """
    Initialize various regression models with optional custom parameters and random state.
    
    Args:
    model_name (str): The name of the model to initialize.
    custom_params (dict, optional): Custom parameters for the model.
    random_state (int, optional): Random seed for reproducibility, defaults to None.

    Returns:
    model: Initialized model object.
    """
    model_defaults = {
        'RF': RandomForestRegressor,
        'GB': GradientBoostingRegressor,
        'KNN': KNeighborsRegressor,
        'DT': DecisionTreeRegressor,
        'SVR': SVR,
        'BG': BaggingRegressor,
        'ET': ExtraTreesRegressor,
        'BR': BayesianRidge,
        'Ridge': Ridge,
        'XGB': XGBRegressor
    }

    model_class = model_defaults.get(model_name)
    if not model_class:
        raise ValueError(f"{model_name} is not a valid model name.")

    # Prepare parameters to initialize the model
    params = custom_params if custom_params else {}
    if 'random_state' in inspect.signature(model_class).parameters:
        params['random_state'] = random_state

    # Initialize and return the model
    return model_class(**params)

# %%
model_names = ['RF', 'GB', 'KNN', 'DT', 'SVR', 'BG', 'ET', 'BR',  'Ridge', 'XGB']
kfold = KFold(n_splits=10,shuffle=True,random_state=random_seed)
performance_result = {}
for model_name in model_names:

    model_params = best_params.get(model_name)

    model = initialize_model(model_name, model_params,random_state=random_seed)
    for desc_name, file_path in datasets.items():
        full_path = os.path.join(directory, file_path)
        if os.path.exists(full_path):
            with np.load(full_path, allow_pickle=True) as npz_file:
                data = npz_file['data']
                columns = npz_file['columns']
                df = pd.DataFrame(data, columns=columns)

                all_indices = set(range(len(df)))
                train_val_indices = sorted(list(all_indices - set(test_index) - set(External_index))) 

                X, y = df.drop(columns=['YRed/Ox', 'compound_name']), df['YRed/Ox']

                scaler = StandardScaler()
                X_scaled = scaler.fit_transform(X.iloc[train_val_indices])
                y_train_val = y.iloc[train_val_indices]
                all_test_p = []
                all_test_y = []
                for train_idx, test_idx in kfold.split(X_scaled, y_train_val):
                    train_x, test_x = X_scaled[train_idx], X_scaled[test_idx]
                    train_y, test_y = y_train_val.iloc[train_idx], y_train_val.iloc[test_idx]
                    test_P = []
                    for try_ in range(10): 
                        model.fit(train_x,train_y)
                        test_p = model.predict(test_x)
                        test_P.append(test_p)
                    test_p = np.mean(test_P,axis=0)
                    all_test_p.append(test_p)
                    all_test_y.append(test_y)
                all_test_p = np.concatenate(all_test_p)
                all_test_y = np.concatenate(all_test_y)
                mae = mean_absolute_error(all_test_y,all_test_p)
                r2 = r2_score(all_test_y,all_test_p)
                pearson_r,_ = pearsonr(all_test_y,all_test_p)
                performance_result[(model_name,desc_name)] = [mae,r2,pearson_r,all_test_y,all_test_p]
                print('Model: %4s, Desc: %4s, R2: %.4f, PearsonR: %.4f, MAE: %.4f'%(model_name,desc_name,r2,pearson_r,mae))
# Out:
# Model:   RF, Desc:   MF, R2: 0.4978, PearsonR: 0.7057, MAE: 0.1534
# Model:   RF, Desc: MACCS, R2: 0.5666, PearsonR: 0.7540, MAE: 0.1416
# Model:   RF, Desc:  PhO, R2: 0.8005, PearsonR: 0.8955, MAE: 0.0912
# Model:   RF, Desc: rdkit, R2: 0.5915, PearsonR: 0.7756, MAE: 0.1321
# Model:   RF, Desc: PhO_rdkit, R2: 0.7944, PearsonR: 0.8920, MAE: 0.0911
# Model:   RF, Desc: PhO_maccs, R2: 0.8029, PearsonR: 0.8967, MAE: 0.0905
# Model:   RF, Desc: PhO_MF, R2: 0.8001, PearsonR: 0.8952, MAE: 0.0906
# Model:   RF, Desc: rdkit_maccs, R2: 0.6068, PearsonR: 0.7860, MAE: 0.1302
# Model:   RF, Desc: PhO_rdkit_maccs, R2: 0.7983, PearsonR: 0.8943, MAE: 0.0904
# Model:   GB, Desc:   MF, R2: 0.4892, PearsonR: 0.7008, MAE: 0.1606
# Model:   GB, Desc: MACCS, R2: 0.5602, PearsonR: 0.7493, MAE: 0.1401
# Model:   GB, Desc:  PhO, R2: 0.8163, PearsonR: 0.9041, MAE: 0.0899
# Model:   GB, Desc: rdkit, R2: 0.6350, PearsonR: 0.7976, MAE: 0.1260
# Model:   GB, Desc: PhO_rdkit, R2: 0.8324, PearsonR: 0.9139, MAE: 0.0834
# Model:   GB, Desc: PhO_maccs, R2: 0.8266, PearsonR: 0.9098, MAE: 0.0868
# Model:   GB, Desc: PhO_MF, R2: 0.8304, PearsonR: 0.9121, MAE: 0.0869
# Model:   GB, Desc: rdkit_maccs, R2: 0.6640, PearsonR: 0.8159, MAE: 0.1217
# Model:   GB, Desc: PhO_rdkit_maccs, R2: 0.8361, PearsonR: 0.9156, MAE: 0.0856
# Model:  KNN, Desc:   MF, R2: 0.2504, PearsonR: 0.5171, MAE: 0.1956
# Model:  KNN, Desc: MACCS, R2: 0.2890, PearsonR: 0.5571, MAE: 0.2009
# Model:  KNN, Desc:  PhO, R2: 0.6106, PearsonR: 0.7853, MAE: 0.1413
# Model:  KNN, Desc: rdkit, R2: 0.4233, PearsonR: 0.6550, MAE: 0.1669
# Model:  KNN, Desc: PhO_rdkit, R2: 0.5991, PearsonR: 0.7793, MAE: 0.1351
# Model:  KNN, Desc: PhO_maccs, R2: 0.6146, PearsonR: 0.7876, MAE: 0.1325
# Model:  KNN, Desc: PhO_MF, R2: 0.4884, PearsonR: 0.7320, MAE: 0.1577
# Model:  KNN, Desc: rdkit_maccs, R2: 0.4602, PearsonR: 0.6895, MAE: 0.1656
# Model:  KNN, Desc: PhO_rdkit_maccs, R2: 0.6190, PearsonR: 0.7945, MAE: 0.1327
# Model:   DT, Desc:   MF, R2: 0.2319, PearsonR: 0.5930, MAE: 0.1904
# Model:   DT, Desc: MACCS, R2: 0.2156, PearsonR: 0.5929, MAE: 0.1830
# Model:   DT, Desc:  PhO, R2: 0.6334, PearsonR: 0.8162, MAE: 0.1305
# Model:   DT, Desc: rdkit, R2: 0.3816, PearsonR: 0.6712, MAE: 0.1698
# Model:   DT, Desc: PhO_rdkit, R2: 0.6756, PearsonR: 0.8338, MAE: 0.1285
# Model:   DT, Desc: PhO_maccs, R2: 0.6759, PearsonR: 0.8387, MAE: 0.1217
# Model:   DT, Desc: PhO_MF, R2: 0.6658, PearsonR: 0.8249, MAE: 0.1282
# Model:   DT, Desc: rdkit_maccs, R2: 0.3527, PearsonR: 0.6672, MAE: 0.1705
# Model:   DT, Desc: PhO_rdkit_maccs, R2: 0.6771, PearsonR: 0.8335, MAE: 0.1273
# Model:  SVR, Desc:   MF, R2: 0.4182, PearsonR: 0.6790, MAE: 0.1788
# Model:  SVR, Desc: MACCS, R2: 0.5592, PearsonR: 0.7623, MAE: 0.1439
# Model:  SVR, Desc:  PhO, R2: 0.6840, PearsonR: 0.8300, MAE: 0.1128
# Model:  SVR, Desc: rdkit, R2: 0.5733, PearsonR: 0.7705, MAE: 0.1456
# Model:  SVR, Desc: PhO_rdkit, R2: 0.6110, PearsonR: 0.7897, MAE: 0.1278
# Model:  SVR, Desc: PhO_maccs, R2: 0.6547, PearsonR: 0.8173, MAE: 0.1210
# Model:  SVR, Desc: PhO_MF, R2: 0.5529, PearsonR: 0.7702, MAE: 0.1528
# Model:  SVR, Desc: rdkit_maccs, R2: 0.6152, PearsonR: 0.8020, MAE: 0.1408
# Model:  SVR, Desc: PhO_rdkit_maccs, R2: 0.6369, PearsonR: 0.8094, MAE: 0.1256
# Model:   BG, Desc:   MF, R2: 0.4453, PearsonR: 0.6703, MAE: 0.1620
# Model:   BG, Desc: MACCS, R2: 0.5619, PearsonR: 0.7530, MAE: 0.1422
# Model:   BG, Desc:  PhO, R2: 0.7719, PearsonR: 0.8788, MAE: 0.0998
# Model:   BG, Desc: rdkit, R2: 0.5551, PearsonR: 0.7464, MAE: 0.1449
# Model:   BG, Desc: PhO_rdkit, R2: 0.7869, PearsonR: 0.8873, MAE: 0.0956
# Model:   BG, Desc: PhO_maccs, R2: 0.7775, PearsonR: 0.8819, MAE: 0.0983
# Model:   BG, Desc: PhO_MF, R2: 0.7785, PearsonR: 0.8825, MAE: 0.0978
# Model:   BG, Desc: rdkit_maccs, R2: 0.5745, PearsonR: 0.7590, MAE: 0.1432
# Model:   BG, Desc: PhO_rdkit_maccs, R2: 0.7635, PearsonR: 0.8739, MAE: 0.0981
# Model:   ET, Desc:   MF, R2: 0.3052, PearsonR: 0.6221, MAE: 0.1844
# Model:   ET, Desc: MACCS, R2: 0.3213, PearsonR: 0.6371, MAE: 0.1696
# Model:   ET, Desc:  PhO, R2: 0.7926, PearsonR: 0.8904, MAE: 0.0883
# Model:   ET, Desc: rdkit, R2: 0.6674, PearsonR: 0.8212, MAE: 0.1151
# Model:   ET, Desc: PhO_rdkit, R2: 0.7893, PearsonR: 0.8886, MAE: 0.0862
# Model:   ET, Desc: PhO_maccs, R2: 0.8416, PearsonR: 0.9182, MAE: 0.0794
# Model:   ET, Desc: PhO_MF, R2: 0.8068, PearsonR: 0.8983, MAE: 0.0845
# Model:   ET, Desc: rdkit_maccs, R2: 0.7331, PearsonR: 0.8595, MAE: 0.1074
# Model:   ET, Desc: PhO_rdkit_maccs, R2: 0.8281, PearsonR: 0.9113, MAE: 0.0816
# Model:   BR, Desc:   MF, R2: 0.5304, PearsonR: 0.7292, MAE: 0.1441
# Model:   BR, Desc: MACCS, R2: 0.4504, PearsonR: 0.6734, MAE: 0.1649
# Model:   BR, Desc:  PhO, R2: 0.9254, PearsonR: 0.9621, MAE: 0.0618
# Model:   BR, Desc: rdkit, R2: 0.7133, PearsonR: 0.8458, MAE: 0.1273
# Model:   BR, Desc: PhO_rdkit, R2: 0.8912, PearsonR: 0.9445, MAE: 0.0784
# Model:   BR, Desc: PhO_maccs, R2: 0.8766, PearsonR: 0.9367, MAE: 0.0822
# Model:   BR, Desc: PhO_MF, R2: 0.8160, PearsonR: 0.9042, MAE: 0.0924
# Model:   BR, Desc: rdkit_maccs, R2: 0.7443, PearsonR: 0.8639, MAE: 0.1213
# Model:   BR, Desc: PhO_rdkit_maccs, R2: 0.8830, PearsonR: 0.9400, MAE: 0.0815
# Model: Ridge, Desc:   MF, R2: 0.4818, PearsonR: 0.7234, MAE: 0.1531
# Model: Ridge, Desc: MACCS, R2: 0.0868, PearsonR: 0.5555, MAE: 0.1893
# Model: Ridge, Desc:  PhO, R2: 0.9271, PearsonR: 0.9629, MAE: 0.0620
# Model: Ridge, Desc: rdkit, R2: 0.5546, PearsonR: 0.7844, MAE: 0.1432
# Model: Ridge, Desc: PhO_rdkit, R2: 0.8668, PearsonR: 0.9338, MAE: 0.0791
# Model: Ridge, Desc: PhO_maccs, R2: 0.8830, PearsonR: 0.9405, MAE: 0.0802
# Model: Ridge, Desc: PhO_MF, R2: 0.7682, PearsonR: 0.8817, MAE: 0.1104
# Model: Ridge, Desc: rdkit_maccs, R2: 0.5546, PearsonR: 0.7943, MAE: 0.1490
# Model: Ridge, Desc: PhO_rdkit_maccs, R2: 0.8241, PearsonR: 0.9151, MAE: 0.0943
# Model:   GP, Desc:   MF, R2: -6.6808, PearsonR: 0.0109, MAE: 0.9451
# Model:   GP, Desc: MACCS, R2: -4.0770, PearsonR: 0.1659, MAE: 0.6532
# Model:   GP, Desc:  PhO, R2: -5.6290, PearsonR: 0.1009, MAE: 0.8618
# Model:   GP, Desc: rdkit, R2: -5.9961, PearsonR: 0.0345, MAE: 0.8726
# Model:   GP, Desc: PhO_rdkit, R2: -6.5278, PearsonR: 0.0012, MAE: 0.9338
# Model:   GP, Desc: PhO_maccs, R2: -6.4314, PearsonR: -0.0093, MAE: 0.9252
# Model:   GP, Desc: PhO_MF, R2: -6.7551, PearsonR: -0.0590, MAE: 0.9522
# Model:   GP, Desc: rdkit_maccs, R2: -6.1314, PearsonR: 0.0196, MAE: 0.8824
# Model:   GP, Desc: PhO_rdkit_maccs, R2: -6.5590, PearsonR: -0.0096, MAE: 0.9359
# Model:  XGB, Desc:   MF, R2: 0.5201, PearsonR: 0.7280, MAE: 0.1458
# Model:  XGB, Desc: MACCS, R2: 0.5715, PearsonR: 0.7623, MAE: 0.1400
# Model:  XGB, Desc:  PhO, R2: 0.7438, PearsonR: 0.8625, MAE: 0.1000
# Model:  XGB, Desc: rdkit, R2: 0.5710, PearsonR: 0.7562, MAE: 0.1405
# Model:  XGB, Desc: PhO_rdkit, R2: 0.7614, PearsonR: 0.8726, MAE: 0.0971
# Model:  XGB, Desc: PhO_maccs, R2: 0.7585, PearsonR: 0.8710, MAE: 0.0975
# Model:  XGB, Desc: PhO_MF, R2: 0.7482, PearsonR: 0.8651, MAE: 0.0962
# Model:  XGB, Desc: rdkit_maccs, R2: 0.5898, PearsonR: 0.7685, MAE: 0.1367
# Model:  XGB, Desc: PhO_rdkit_maccs, R2: 0.7529, PearsonR: 0.8678, MAE: 0.0985

# %%
np.save('./result/models_descs_screening_10_fold_new.npy',performance_result)

# %% [markdown]
# # Visualization

# %%
performance_result = np.load('./result/models_descs_screening_10_fold_new.npy',allow_pickle=True).item()

# %%
model_names = ['RF', 'GB', 'KNN', 'DT', 'SVR', 'BG', 'ET', 'BR', 'Ridge', 'XGB']
desc_names = list(datasets.keys())
r2_map = np.zeros((len(desc_names),len(model_names)))
r2_min_value = 0

for i, m in enumerate(model_names):
    for j, d in enumerate(desc_names):
            r2_map[j, i] = max(performance_result[(m,d)][1], r2_min_value)

fig = plt.figure(figsize=(18, 10))
sns.set(font_scale=1.2)  
ax = sns.heatmap(r2_map, annot=True, fmt='.3f', xticklabels=model_names, yticklabels=desc_names, cmap='GnBu',cbar=False)

plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig('./result/heatmap.tif', dpi=300) 
plt.savefig('./result/heatmap.png')
plt.show()

# %% [markdown]
# # Validate Model Extrapolativa Ability

# %% [markdown]
# Identify the optimal machine learning model for every descriptor

# %%
import numpy as np

performance_result = np.load('./result/models_descs_screening_10_fold_new.npy', allow_pickle=True).item()

model_names = ['RF', 'GB', 'KNN', 'DT', 'SVR',  'BG', 'ET', 'BR',  'Ridge', 'XGB']

all_combinations = list(performance_result.keys())

best_model_for_specific_desc = []

mae_values = np.array([performance_result[key][0] for key in all_combinations if performance_result[key][0] < 1e10]) 
median_mae = np.median(mae_values)
iqr_mae = np.percentile(mae_values, 75) - np.percentile(mae_values, 25)

w_r2 = 0.6
w_mae = 0.4

r2_threshold = 0.80

for desc_name in set(desc for _, desc in all_combinations):
    best_score = -np.inf
    best_model_entry = None
    for item in all_combinations:
        if item[1] == desc_name:
            mae, r2 = performance_result[item][0], performance_result[item][1]
            
            if r2 > r2_threshold and mae < 1e10:  
                normalized_mae = (median_mae - mae) / iqr_mae 
                score = w_r2 * r2 + w_mae * normalized_mae  
                if score > best_score:
                    best_score = score
                    best_model_entry = [item, r2]
    if best_model_entry:
        best_model_for_specific_desc.append(best_model_entry)

print(best_model_for_specific_desc)
# Out:
# [[('Ridge', 'PhO_maccs'), 0.8829780275533441], [('BR', 'PhO_rdkit_maccs'), 0.8830221827402385], [('BR', 'PhO'), 0.9254446524659009], [('ET', 'PhO_MF'), 0.8068399914800485], [('BR', 'PhO_rdkit'), 0.8911665161838679]]

# %%
import numpy as np

performance_result = np.load('./result/models_descs_screening_10_fold_new.npy', allow_pickle=True).item()

model_names = ['RF', 'GB', 'KNN', 'DT', 'SVR', 'BG', 'ET', 'BR',  'Ridge', 'XGB']

best_desc_for_specific_model = {}

mae_values = [performance_result[key][0] for key in performance_result.keys() if performance_result[key][0] < 1e10] 
median_mae = np.median(mae_values)
iqr_mae = np.percentile(mae_values, 75) - np.percentile(mae_values, 25)

w_r2 = 0.6
w_mae = 0.4

r2_threshold = 0.80

for model in model_names:
    best_score = -np.inf
    best_descriptor = None

    for (m, desc), values in performance_result.items():
        if m == model:
            r2 = values[1] 
            mae = values[0]  
            if r2 > r2_threshold and mae < 1e10:
                normalized_mae = (median_mae - mae) / iqr_mae
                score = w_r2 * r2 + w_mae * normalized_mae
                if score > best_score:
                    best_score = score
                    best_descriptor = (desc, r2)
    if best_descriptor:
        best_desc_for_specific_model[model] = best_descriptor

best_desc_for_specific_model_list = [
    (model, desc, r2) for model, (desc, r2) in best_desc_for_specific_model.items()
]
print(best_desc_for_specific_model_list)
# Out:
# [('RF', 'PhO_maccs', 0.8028764561743658), ('GB', 'PhO_rdkit', 0.8323877261227965), ('ET', 'PhO_maccs', 0.8416175730055482), ('BR', 'PhO', 0.9254446524659009), ('Ridge', 'PhO', 0.9271420819235182)]

# %%
oos_performance = {}
from utils.ModelTraining import init_model, oos_fit_pred, cv_fit_pred, feature_selection, model_evaluation
import importlib
import utils.ModelTraining 

importlib.reload(utils.ModelTraining)
from utils.ModelTraining import init_model, oos_fit_pred, cv_fit_pred, feature_selection, model_evaluation

# %%
oos_x = scaler.transform(X.iloc[test_index])
oos_y = y.iloc[test_index]

# %%
model_name = 'Ridge'
desc_name = 'PhO_maccs'

_, _, cv_mae, cv_r2, cv_pearson_r, _, _, oos_mae, oos_r2, oos_pearson_r = model_evaluation(
    X, y, X_scaled, y_train_val, oos_x, oos_y, best_params, model_name, desc_name, test_index,scaler, random_seed=random_seed)

oos_performance['%s/%s'%(model_name,desc_name)] = [oos_r2,oos_mae]

# %%
model_name = 'BR'
desc_name = 'PhO_rdkit_maccs'

_, _, cv_mae, cv_r2, cv_pearson_r, _, _, oos_mae, oos_r2, oos_pearson_r = model_evaluation(
    X, y, X_scaled, y_train_val, oos_x, oos_y, best_params, model_name, desc_name, test_index,scaler, random_seed=random_seed)

oos_performance['%s/%s'%(model_name,desc_name)] = [oos_r2,oos_mae]

# %%
model_name = 'BR'
desc_name = 'PhO'

_, _, cv_mae, cv_r2, cv_pearson_r, _, _, oos_mae, oos_r2, oos_pearson_r = model_evaluation(
    X, y, X_scaled, y_train_val, oos_x, oos_y, best_params, model_name, desc_name, test_index,scaler, random_seed=random_seed)

oos_performance['%s/%s'%(model_name,desc_name)] = [oos_r2,oos_mae]

# %%
model_name = 'Ridge'
desc_name = 'PhO_maccs'

_, _, cv_mae, cv_r2, cv_pearson_r, _, _, oos_mae, oos_r2, oos_pearson_r = model_evaluation(
    X, y, X_scaled, y_train_val, oos_x, oos_y, best_params, model_name, desc_name, test_index,scaler, random_seed=random_seed)

oos_performance['%s/%s'%(model_name,desc_name)] = [oos_r2,oos_mae]

# %%
model_name = 'ET'
desc_name = 'PhO_MF'

_, _, cv_mae, cv_r2, cv_pearson_r, _, _, oos_mae, oos_r2, oos_pearson_r = model_evaluation(
    X, y, X_scaled, y_train_val, oos_x, oos_y, best_params, model_name, desc_name, test_index,scaler, random_seed=random_seed)

oos_performance['%s/%s'%(model_name,desc_name)] = [oos_r2,oos_mae]

# %%
model_name = 'BR'
desc_name = 'PhO_rdkit'

_, _, cv_mae, cv_r2, cv_pearson_r, _, _, oos_mae, oos_r2, oos_pearson_r = model_evaluation(
    X, y, X_scaled, y_train_val, oos_x, oos_y, best_params, model_name, desc_name, test_index,scaler, random_seed=random_seed)

oos_performance['%s/%s'%(model_name,desc_name)] = [oos_r2,oos_mae]

# %%
model_name = 'RF'
desc_name = 'PhO_maccs'

_, _, cv_mae, cv_r2, cv_pearson_r, _, _, oos_mae, oos_r2, oos_pearson_r = model_evaluation(
    X, y, X_scaled, y_train_val, oos_x, oos_y, best_params, model_name, desc_name, test_index,scaler, random_seed=random_seed)

oos_performance['%s/%s'%(model_name,desc_name)] = [oos_r2,oos_mae]

# %%
model_name = 'GB'
desc_name = 'PhO_rdkit'

_, _, cv_mae, cv_r2, cv_pearson_r, _, _, oos_mae, oos_r2, oos_pearson_r = model_evaluation(
    X, y, X_scaled, y_train_val, oos_x, oos_y, best_params, model_name, desc_name, test_index,scaler, random_seed=random_seed)

oos_performance['%s/%s'%(model_name,desc_name)] = [oos_r2,oos_mae]

# %%
model_name = 'ET'
desc_name = 'PhO_maccs'

_, _, cv_mae, cv_r2, cv_pearson_r, _, _, oos_mae, oos_r2, oos_pearson_r = model_evaluation(
    X, y, X_scaled, y_train_val, oos_x, oos_y, best_params, model_name, desc_name, test_index,scaler, random_seed=random_seed)

oos_performance['%s/%s'%(model_name,desc_name)] = [oos_r2,oos_mae]

# %%
model_name = 'Ridge'
desc_name = 'PhO'

_, _, cv_mae, cv_r2, cv_pearson_r, _, _, oos_mae, oos_r2, oos_pearson_r = model_evaluation(
    X, y, X_scaled, y_train_val, oos_x, oos_y, best_params, model_name, desc_name, test_index,scaler, random_seed=random_seed)

oos_performance['%s/%s'%(model_name,desc_name)] = [oos_r2,oos_mae]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib import colors

sns.set_style('white')

performance_dict = {}

for model_desc_pair, _ in best_model_for_specific_desc:
    model, desc = model_desc_pair
    key = f'{model}/{desc}'
    if key in oos_performance and oos_performance[key][0] >= 0:
        performance_dict[key] = (oos_performance[key][0], oos_performance[key][1])

for model_desc_pair in best_desc_for_specific_model_list:
    model, desc, _ = model_desc_pair
    key = f'{model}/{desc}'
    if key in oos_performance and oos_performance[key][0] >= 0:
        performance_dict[key] = (oos_performance[key][0], oos_performance[key][1])

all_combinations = list(performance_dict.keys())
oos_r2_filtered = [item[0] for item in performance_dict.values()]
oos_mae_filtered = [item[1] for item in performance_dict.values()]

oos_r2_filtered_rounded = [round(value, 3) for value in oos_r2_filtered]
oos_mae_filtered_rounded = [round(value, 3) for value in oos_mae_filtered]

heatmap_r2 = []
for label in all_combinations:
    model_desc_pair = label.split('/')
    key_tuple = (model_desc_pair[0], model_desc_pair[1])
    
    if key_tuple in performance_result:
        heatmap_r2.append(round(performance_result[key_tuple][1], 3)) 
    else:
        heatmap_r2.append(np.nan)  

tickfontsize = 15
labelfontsize = 18

fig, ax1 = plt.subplots(figsize=(18, 8))
ax2 = ax1.twinx()

bar_width = 0.25  
indices = np.arange(len(all_combinations))

mae_colors = ['bisque', 'bisque', 'darkorange', 'bisque', 'bisque', 'bisque', 'bisque', 'bisque', 'bisque']  
r2_colors = ['lightblue', 'lightblue', 'royalblue', 'lightblue', 'lightblue', 'lightblue', 'lightblue', 'lightblue', 'lightblue']  
heatmap_r2_colors = ['lightgreen', 'lightgreen', 'darkgreen', 'lightgreen', 'lightgreen', 'lightgreen', 'lightgreen', 'lightgreen', 'lightgreen']  


ax1.bar(
    indices - bar_width, 
    oos_mae_filtered_rounded, 
    bar_width, 
    color=mae_colors, 
    label='MAE'
)

ax2.bar(
    indices, 
    oos_r2_filtered_rounded, 
    bar_width, 
    color=r2_colors, 
    label='$R^2$'
)

ax2.bar(
    indices + bar_width, 
    heatmap_r2, 
    bar_width, 
    color=heatmap_r2_colors,
    label='Heatmap $R^2$', 
    alpha=0.6
)

formatted_labels = []
for label in all_combinations:
    if label == 'ET/PhO_rdkit_maccs':
        formatted_labels.append('ET/\nPhO_rdkit_maccs')
    else: 
        formatted_labels.append(label)

ax1.set_xticks(indices)
ax1.set_xticklabels(formatted_labels, fontsize=tickfontsize, rotation=60, ha='center')

ax2.set_ylabel('$R^2$', fontsize=labelfontsize, color='royalblue', rotation=270, labelpad=20)
ax1.set_ylabel('MAE (kcal/mol)', fontsize=labelfontsize, color='darkorange')

ax1.legend(loc='upper left', fontsize='small')
ax2.legend(loc='upper right', fontsize='small')

plt.tight_layout()
plt.savefig('./result/combined_models_descs_with_separated_bars.png', dpi=600)
plt.show()
